# %% [markdown]
# # 로라 병합 후 저장하기

# %%
from peft import PeftModel
from transformers import AutoProcessor, AutoModelForVision2Seq

adapter_path = "./qwen2-7b-instruct-harmful-detector-2000/checkpoint-32"  # 학습된 어댑터 경로
base_model_id = "Qwen/Qwen2-VL-7B-Instruct"   # 기본 모델 ID
merged_path = "merged"  # 병합된 모델을 저장할 경로

# 기본 모델 로드
model = AutoModelForVision2Seq.from_pretrained(base_model_id, low_cpu_mem_usage=True)

# 병합된 모델 저장 경로
# LoRA와 기본 모델을 병합하고 저장
peft_model = PeftModel.from_pretrained(model, adapter_path)  # PEFT 모델 로드
merged_model = peft_model.merge_and_unload()  # 모델 병합
merged_model.save_pretrained(merged_path, safe_serialization=True, max_shard_size="5GB")  # 병합된 모델 저장

processor = AutoProcessor.from_pretrained(base_model_id)  # 프로세서 로드
processor.save_pretrained(merged_path)  # 프로세서 저장
# Out:
# Unrecognized keys in `rope_scaling` for 'rope_type'='default': {'mrope_section'}
# `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# []

# %% [markdown]
# # 허깅페이스에 모델 업로드하기

# %%
# 허깅페이스 로그인 
# !huggingface-cli login --token Your_Huggingface_Token

# %%
# !huggingface-cli upload-large-folder --repo-type=model daje/Qwen2-7B-Instruct-harmful_detector_2000-H100_1 /workspace/FASTCAMPUS-CH09_11/chapter09-Multi_Modal/merged
# Out:
# You are about to upload a large folder to the Hub using `huggingface-cli upload-large-folder`. This is a new feature so feedback is very welcome!
#
# A few things to keep in mind:
#   - Repository limits still apply: https://huggingface.co/docs/hub/repositories-recommendations
#   - Do not start several processes in parallel.
#   - You can interrupt and resume the process at any time. The script will pick up where it left off except for partially uploaded files that would have to be entirely reuploaded.
#   - Do not upload the same folder to several repositories. If you need to do so, you must delete the `./.cache/huggingface/` folder first.
#
# Some temporary metadata will be stored under `/workspace/FASTCAMPUS-CH09_11/chapter09-Multi_Modal/merged/.cache/huggingface`.
#   - You must not modify those files manually.
#   - You must not delete the `./.cache/huggingface/` folder while a process is running.
#   - You can delete the `./.cache/huggingface/` folder to reinitialize the upload state when process is not running. Files will have to be hashed and preuploaded again, except for already committed files.
#
# If the process output is too verbose, you can disable the progress bars with `--no-bars`. You can also entirely disable the status report with `--no-report`.
#
# For more details, run `huggingface-cli upload-large-folder --help` or check the documentation at https://huggingface.co/docs/huggingface_hub/guides/upload#upload-a-large-folder.
# Repo created: https://huggingface.co/daje/Qwen2-7B-Instruct-harmful_detector_2000-H100_1
# Found 18 candidate files to upload
# Recovering from metadata files: 100%|█████████| 18/18 [00:00<00:00, 2928.30it/s]
#
#
#
# ---------- 2025-02-25 07:24:19 (0:00:00) ----------
# Files:   hashed 18/18 (33.2G/33.2G) | pre-uploaded: 1/8 (11.4M/33.2G) | committed: 0/18 (0.0/33.2G) | ignored: 0
# Workers: hashing: 0 | get upload mode: 0 | pre-uploading: 7 | committing: 0 | waiting: 247
# ---------------------------------------------------
# model-00007-of-00007.safetensors:   0%|             | 0.00/3.38G [00:00<?, ?B/s]
# model-00002-of-00007.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
#
# model-00004-of-00007.safetensors:   0%|             | 0.00/5.00G [00:00<?, ?B/s]
#
#
# model-00006-of-00007.safetensors:   0%|             | 0.00/4.93G [00:00<?, ?B/s]
#
#
#
# model-00005-of-00007.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
#
#
#
#
# model-00007-of-00007.safetensors:   0%|   | 16.4k/3.38G [00:00<5:56:35, 158kB/s]
# model-00002-of-00007.safetensors:   0%|   | 16.4k/4.98G [00:00<8:36:28, 161kB/s]
# model-00007-of-00007.safetensors:   0%|    | 2.59M/3.38G [00:00<04:33, 12.4MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   0%|    | 2.59M/4.95G [00:00<05:32, 14.9MB/s]
#
# model-00004-of-00007.safetensors:   0%|    | 2.59M/5.00G [00:00<08:28, 9.83MB/s]
#
#
# model-00006-of-00007.safetensors:   0%|    | 2.59M/4.93G [00:00<08:07, 10.1MB/s]
#
#
#
# model-00005-of-00007.safetensors:   0%|    | 2.59M/4.98G [00:00<08:04, 10.3MB/s]
# model-00007-of-00007.safetensors:   0%|    | 8.29M/3.38G [00:00<01:54, 29.4MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   0%|    | 5.52M/4.95G [00:00<04:04, 20.3MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   0%|             | 0.00/4.93G [00:00<?, ?B/s]
#
#
#
# model-00005-of-00007.safetensors:   0%|    | 4.29M/4.98G [00:00<06:56, 12.0MB/s]
# model-00002-of-00007.safetensors:   0%|    | 7.41M/4.98G [00:00<04:09, 19.9MB/s]
#
#
# model-00006-of-00007.safetensors:   0%|    | 8.60M/4.93G [00:00<03:44, 22.0MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   0%|    | 12.3M/4.95G [00:00<02:23, 34.3MB/s]
#
# model-00007-of-00007.safetensors:   0%|    | 11.3M/3.38G [00:00<02:11, 25.7MB/s]
#
#
#
# model-00005-of-00007.safetensors:   0%|    | 13.4M/4.98G [00:00<02:29, 33.2MB/s]
# model-00002-of-00007.safetensors:   0%|    | 9.40M/4.98G [00:00<04:42, 17.6MB/s]
#
#
# model-00006-of-00007.safetensors:   0%|    | 15.5M/4.93G [00:00<02:18, 35.5MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   0%|    | 15.8M/4.95G [00:00<02:47, 29.4MB/s]
# model-00007-of-00007.safetensors:   0%|    | 16.0M/3.38G [00:00<02:29, 22.5MB/s]
#
# model-00004-of-00007.safetensors:   0%|    | 17.0M/5.00G [00:00<03:39, 22.7MB/s]
#
#
# model-00006-of-00007.safetensors:   0%|    | 20.0M/4.93G [00:00<02:44, 29.9MB/s]
#
#
#
# model-00005-of-00007.safetensors:   0%|    | 17.0M/4.98G [00:00<03:17, 25.2MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:   1%|    | 21.4M/3.38G [00:00<01:52, 29.8MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   0%|    | 2.59M/4.93G [00:00<15:07, 5.43MB/s]
#
# model-00004-of-00007.safetensors:   0%|    | 22.8M/5.00G [00:00<02:57, 28.1MB/s]
#
#
# model-00006-of-00007.safetensors:   1%|    | 27.9M/4.93G [00:00<02:06, 38.8MB/s]
#
#
#
# model-00005-of-00007.safetensors:   0%|    | 22.3M/4.98G [00:00<02:45, 30.0MB/s]
# model-00002-of-00007.safetensors:   0%|    | 17.5M/4.98G [00:00<04:07, 20.0MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:   1%|    | 25.1M/3.38G [00:00<01:48, 30.9MB/s]
#
#
#
# model-00005-of-00007.safetensors:   1%|    | 25.7M/4.98G [00:00<02:38, 31.2MB/s]
#
# model-00004-of-00007.safetensors:   1%|    | 26.1M/5.00G [00:00<02:55, 28.4MB/s]
# model-00007-of-00007.safetensors:   1%|    | 29.2M/3.38G [00:01<01:54, 29.4MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 26.6M/4.95G [00:01<03:21, 24.5MB/s]
#
# model-00004-of-00007.safetensors:   1%|    | 29.2M/5.00G [00:01<02:55, 28.3MB/s]
# model-00002-of-00007.safetensors:   1%|    | 26.9M/4.98G [00:01<03:09, 26.2MB/s]
#
#
#
# model-00005-of-00007.safetensors:   1%|    | 29.2M/4.98G [00:01<03:25, 24.2MB/s]
#
#
# model-00006-of-00007.safetensors:   1%|    | 32.4M/4.93G [00:01<03:11, 25.6MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 29.4M/4.95G [00:01<03:46, 21.7MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   0%|    | 3.52M/4.93G [00:00<23:55, 3.43MB/s]
#
#
# model-00006-of-00007.safetensors:   1%|    | 37.6M/4.93G [00:01<03:11, 25.6MB/s]
#
#
#
# model-00007-of-00007.safetensors:   1%|    | 32.3M/3.38G [00:01<03:06, 17.9MB/s]
#
# model-00004-of-00007.safetensors:   1%|    | 32.3M/5.00G [00:01<04:35, 18.0MB/s]
# model-00002-of-00007.safetensors:   1%|    | 32.0M/4.98G [00:01<03:39, 22.6MB/s]
#
#
# model-00006-of-00007.safetensors:   1%|    | 41.6M/4.93G [00:01<02:55, 27.8MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 32.0M/4.95G [00:01<05:23, 15.2MB/s]
#
# model-00007-of-00007.safetensors:   1%|    | 36.3M/3.38G [00:01<02:43, 20.4MB/s]
#
#
#
# model-00005-of-00007.safetensors:   1%|    | 36.4M/4.98G [00:01<03:39, 22.6MB/s]
# model-00002-of-00007.safetensors:   1%|    | 36.1M/4.98G [00:01<03:16, 25.2MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   0%|    | 4.42M/4.93G [00:01<27:34, 2.98MB/s]
#
# model-00004-of-00007.safetensors:   1%|    | 40.4M/5.00G [00:01<03:27, 24.0MB/s]
#
#
#
# model-00005-of-00007.safetensors:   1%|    | 39.0M/4.98G [00:01<03:47, 21.8MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 33.9M/4.95G [00:01<05:45, 14.2MB/s]
#
#
# model-00007-of-00007.safetensors:   1%|    | 38.9M/3.38G [00:01<03:00, 18.6MB/s]
# model-00002-of-00007.safetensors:   1%|    | 39.3M/4.98G [00:01<03:36, 22.9MB/s]
#
# model-00004-of-00007.safetensors:   1%|    | 46.3M/5.00G [00:01<03:04, 26.9MB/s]
# model-00002-of-00007.safetensors:   1%|    | 42.1M/4.98G [00:01<03:27, 23.9MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   0%|    | 5.39M/4.93G [00:01<26:03, 3.15MB/s]
#
#
#
# model-00005-of-00007.safetensors:   1%|    | 41.4M/4.98G [00:01<04:40, 17.6MB/s]
#
#
# model-00007-of-00007.safetensors:   1%|    | 41.9M/3.38G [00:01<03:08, 17.7MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 37.5M/4.95G [00:01<05:22, 15.2MB/s]
#
#
#
# model-00007-of-00007.safetensors:   1%|    | 45.4M/3.38G [00:02<02:38, 21.0MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   0%|    | 7.18M/4.93G [00:01<18:48, 4.37MB/s]
#
# model-00004-of-00007.safetensors:   1%|    | 49.3M/5.00G [00:02<04:34, 18.0MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 41.7M/4.95G [00:02<05:25, 15.1MB/s]
# model-00002-of-00007.safetensors:   1%|    | 48.0M/4.98G [00:02<04:08, 19.9MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 45.4M/4.95G [00:02<04:22, 18.7MB/s]
#
# model-00004-of-00007.safetensors:   1%|    | 51.6M/5.00G [00:02<04:24, 18.7MB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:   1%|    | 47.9M/3.38G [00:02<03:51, 14.4MB/s]
#
#
# model-00006-of-00007.safetensors:   1%|    | 50.0M/4.93G [00:02<06:24, 12.7MB/s]
#
# model-00004-of-00007.safetensors:   1%|    | 55.2M/5.00G [00:02<03:46, 21.8MB/s]
#
#
#
# model-00005-of-00007.safetensors:   1%|    | 48.0M/4.98G [00:02<05:51, 14.0MB/s]
# model-00002-of-00007.safetensors:   1%|    | 52.3M/4.98G [00:02<04:13, 19.4MB/s]
#
# model-00004-of-00007.safetensors:   1%|    | 58.3M/5.00G [00:02<03:44, 22.0MB/s]
# model-00002-of-00007.safetensors:   1%|    | 55.0M/4.98G [00:02<04:03, 20.2MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 47.7M/4.95G [00:02<05:26, 15.0MB/s]
#
#
# model-00006-of-00007.safetensors:   1%|    | 51.8M/4.93G [00:02<06:52, 11.8MB/s]
#
#
#
# model-00005-of-00007.safetensors:   1%|    | 49.9M/4.98G [00:02<05:57, 13.8MB/s]
#
# model-00004-of-00007.safetensors:   1%|    | 60.8M/5.00G [00:02<03:49, 21.5MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   0%|    | 9.24M/4.93G [00:02<20:59, 3.91MB/s]
# model-00002-of-00007.safetensors:   1%|    | 57.8M/4.98G [00:02<04:04, 20.1MB/s]
#
#
# model-00006-of-00007.safetensors:   1%|    | 55.7M/4.93G [00:02<05:26, 14.9MB/s]
#
#
#
# model-00007-of-00007.safetensors:   1%|    | 49.9M/3.38G [00:02<05:06, 10.9MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   0%|    | 10.5M/4.93G [00:02<16:21, 5.01MB/s]
#
#
# model-00006-of-00007.safetensors:   1%|    | 61.2M/4.93G [00:02<03:45, 21.6MB/s]
#
# model-00004-of-00007.safetensors:   1%|    | 63.2M/5.00G [00:02<04:02, 20.3MB/s]
# model-00007-of-00007.safetensors:   2%|    | 52.7M/3.38G [00:02<04:33, 12.2MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 49.5M/4.95G [00:02<07:11, 11.4MB/s]
#
#
#
# model-00005-of-00007.safetensors:   1%|    | 54.8M/4.98G [00:02<05:27, 15.0MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   0%|    | 13.0M/4.93G [00:02<11:03, 7.41MB/s]
# model-00007-of-00007.safetensors:   2%|    | 54.7M/3.38G [00:03<04:07, 13.4MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 52.2M/4.95G [00:02<05:58, 13.7MB/s]
#
#
#
# model-00005-of-00007.safetensors:   1%|    | 56.9M/4.98G [00:02<05:07, 16.0MB/s]
#
# model-00004-of-00007.safetensors:   1%|    | 65.4M/5.00G [00:03<05:23, 15.3MB/s]
#
#
# model-00006-of-00007.safetensors:   1%|    | 64.2M/4.93G [00:03<04:39, 17.4MB/s]
#
#
#
# model-00005-of-00007.safetensors:   1%|    | 59.7M/4.98G [00:03<04:25, 18.5MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 54.3M/4.95G [00:03<05:30, 14.8MB/s]
# model-00007-of-00007.safetensors:   2%|    | 57.7M/3.38G [00:03<03:39, 15.2MB/s]
#
# model-00004-of-00007.safetensors:   1%|    | 67.2M/5.00G [00:03<05:14, 15.7MB/s]
#
#
# model-00006-of-00007.safetensors:   1%|    | 68.6M/4.93G [00:03<03:41, 22.0MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 56.2M/4.95G [00:03<05:11, 15.7MB/s]
#
# model-00007-of-00007.safetensors:   2%|    | 61.2M/3.38G [00:03<03:21, 16.5MB/s]
#
#
#
# model-00005-of-00007.safetensors:   1%|    | 61.7M/4.98G [00:03<05:34, 14.7MB/s]
#
#
# model-00006-of-00007.safetensors:   1%|    | 71.7M/4.93G [00:03<03:41, 21.9MB/s]
# model-00002-of-00007.safetensors:   1%|    | 65.7M/4.98G [00:03<06:32, 12.5MB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:   2%|    | 63.1M/3.38G [00:03<03:28, 15.9MB/s]
#
# model-00004-of-00007.safetensors:   2%|    | 77.7M/5.00G [00:03<03:03, 26.9MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 58.1M/4.95G [00:03<06:40, 12.2MB/s]
#
#
# model-00006-of-00007.safetensors:   2%|    | 74.4M/4.93G [00:03<03:40, 22.0MB/s]
#
#
#
# model-00005-of-00007.safetensors:   1%|    | 64.0M/4.98G [00:03<05:53, 13.9MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   0%|    | 20.0M/4.93G [00:03<07:21, 11.1MB/s]
# model-00002-of-00007.safetensors:   1%|    | 68.1M/4.98G [00:03<06:11, 13.2MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 60.2M/4.95G [00:03<05:54, 13.8MB/s]
#
#
# model-00006-of-00007.safetensors:   2%|    | 78.1M/4.93G [00:03<03:12, 25.2MB/s]
#
#
#
# model-00007-of-00007.safetensors:   2%|    | 64.8M/3.38G [00:03<04:32, 12.2MB/s]
# model-00002-of-00007.safetensors:   1%|    | 71.4M/4.98G [00:03<05:43, 14.3MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   0%|    | 22.0M/4.93G [00:03<07:34, 10.8MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 63.5M/4.95G [00:03<05:34, 14.6MB/s]
#
#
# model-00007-of-00007.safetensors:   2%|    | 68.1M/3.38G [00:03<03:33, 15.5MB/s]
#
#
#
# model-00005-of-00007.safetensors:   1%|    | 71.0M/4.98G [00:03<04:27, 18.4MB/s]
# model-00002-of-00007.safetensors:   1%|    | 73.4M/4.98G [00:03<05:20, 15.3MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   0%|    | 24.4M/4.93G [00:03<06:20, 12.9MB/s]
#
# model-00004-of-00007.safetensors:   2%|    | 80.5M/5.00G [00:03<05:18, 15.5MB/s]
#
#
# model-00006-of-00007.safetensors:   2%|    | 86.7M/4.93G [00:03<03:01, 26.7MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:   2%|    | 72.0M/3.38G [00:04<02:58, 18.6MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 28.2M/4.93G [00:03<04:54, 16.7MB/s]
#
#
# model-00006-of-00007.safetensors:   2%|    | 90.1M/4.93G [00:04<03:04, 26.3MB/s]
#
# model-00004-of-00007.safetensors:   2%|    | 85.9M/5.00G [00:04<04:06, 20.0MB/s]
#
#
#
# model-00005-of-00007.safetensors:   2%|    | 75.3M/4.98G [00:04<04:14, 19.3MB/s]
# model-00002-of-00007.safetensors:   2%|    | 80.0M/4.98G [00:04<04:16, 19.1MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 30.2M/4.93G [00:03<05:04, 16.1MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   1%|    | 71.3M/4.95G [00:04<04:05, 19.9MB/s]
#
#
# model-00007-of-00007.safetensors:   2%|    | 75.8M/3.38G [00:04<03:00, 18.4MB/s]
#
# model-00004-of-00007.safetensors:   2%|    | 88.6M/5.00G [00:04<04:14, 19.3MB/s]
#
#
#
# model-00005-of-00007.safetensors:   2%|    | 77.3M/4.98G [00:04<04:42, 17.3MB/s]
# model-00002-of-00007.safetensors:   2%|    | 85.9M/4.98G [00:04<03:16, 25.0MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:   2%|    | 77.8M/3.38G [00:04<03:18, 16.7MB/s]
#
# model-00004-of-00007.safetensors:   2%|    | 91.0M/5.00G [00:04<04:31, 18.1MB/s]
# model-00002-of-00007.safetensors:   2%|    | 88.6M/4.98G [00:04<03:18, 24.7MB/s]
#
#
#
# model-00005-of-00007.safetensors:   2%|    | 80.0M/4.98G [00:04<04:46, 17.1MB/s]
#
# model-00004-of-00007.safetensors:   2%|    | 93.1M/5.00G [00:04<04:52, 16.8MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   2%|    | 75.4M/4.95G [00:04<05:30, 14.8MB/s]
#
#
# model-00006-of-00007.safetensors:   2%|    | 99.7M/4.93G [00:04<04:02, 19.9MB/s]
#
#
#
# model-00005-of-00007.safetensors:   2%|    | 84.1M/4.98G [00:04<05:20, 15.3MB/s]
# model-00002-of-00007.safetensors:   2%|    | 91.1M/4.98G [00:04<04:53, 16.7MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   2%|    | 77.0M/4.95G [00:04<06:12, 13.1MB/s]
#
#
# model-00006-of-00007.safetensors:   2%|     | 103M/4.93G [00:04<04:10, 19.3MB/s]
#
#
#
# model-00005-of-00007.safetensors:   2%|    | 88.5M/4.98G [00:04<04:13, 19.3MB/s]
#
#
# model-00007-of-00007.safetensors:   2%|    | 80.0M/3.38G [00:04<05:27, 10.1MB/s]
# model-00002-of-00007.safetensors:   2%|    | 96.0M/4.98G [00:04<04:10, 19.5MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 32.1M/4.93G [00:04<11:43, 6.96MB/s]
#
# model-00004-of-00007.safetensors:   2%|    | 96.0M/5.00G [00:04<06:35, 12.4MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   2%|    | 80.0M/4.95G [00:04<05:59, 13.5MB/s]
#
#
#
# model-00005-of-00007.safetensors:   2%|    | 93.1M/4.98G [00:04<03:53, 20.9MB/s]
#
# model-00004-of-00007.safetensors:   2%|     | 100M/5.00G [00:05<04:47, 17.1MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 33.7M/4.93G [00:04<10:30, 7.77MB/s]
# model-00002-of-00007.safetensors:   2%|     | 101M/4.98G [00:05<03:26, 23.6MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:   3%|    | 85.7M/3.38G [00:05<03:48, 14.5MB/s]
#
#
# model-00006-of-00007.safetensors:   2%|     | 112M/4.93G [00:05<03:40, 21.8MB/s]
#
# model-00004-of-00007.safetensors:   2%|     | 103M/5.00G [00:05<04:18, 18.9MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 37.6M/4.93G [00:04<06:56, 11.8MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:   3%|    | 87.5M/3.38G [00:05<03:50, 14.3MB/s]
#
#
#
# model-00005-of-00007.safetensors:   2%|    | 96.0M/4.98G [00:05<04:22, 18.6MB/s]
# model-00002-of-00007.safetensors:   2%|     | 107M/4.98G [00:05<03:26, 23.6MB/s]
#
#
# model-00006-of-00007.safetensors:   2%|     | 118M/4.93G [00:05<03:09, 25.4MB/s]
#
# model-00004-of-00007.safetensors:   2%|     | 106M/5.00G [00:05<04:41, 17.4MB/s]
#
#
#
# model-00005-of-00007.safetensors:   2%|    | 98.6M/4.98G [00:05<04:26, 18.3MB/s]
#
#
# model-00007-of-00007.safetensors:   3%|    | 89.2M/3.38G [00:05<04:49, 11.4MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 40.7M/4.93G [00:05<07:38, 10.7MB/s]
#
#
#
# model-00005-of-00007.safetensors:   2%|     | 101M/4.98G [00:05<04:26, 18.3MB/s]
# model-00002-of-00007.safetensors:   2%|     | 109M/4.98G [00:05<04:08, 19.6MB/s]
#
#
# model-00006-of-00007.safetensors:   3%|▏    | 124M/4.93G [00:05<03:18, 24.3MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   2%|    | 88.5M/4.95G [00:05<06:29, 12.5MB/s]
#
# model-00007-of-00007.safetensors:   3%|    | 93.3M/3.38G [00:05<03:26, 16.0MB/s]
#
#
#
# model-00005-of-00007.safetensors:   2%|     | 106M/4.98G [00:05<03:41, 22.0MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:   3%|    | 95.8M/3.38G [00:05<03:24, 16.1MB/s]
#
#
# model-00006-of-00007.safetensors:   3%|▏    | 127M/4.93G [00:05<03:45, 21.3MB/s]
# model-00002-of-00007.safetensors:   2%|     | 112M/4.98G [00:05<05:27, 14.9MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 45.4M/4.93G [00:05<07:07, 11.4MB/s]
#
# model-00004-of-00007.safetensors:   2%|     | 112M/5.00G [00:05<06:29, 12.6MB/s]
#
#
#
# model-00005-of-00007.safetensors:   2%|     | 109M/4.98G [00:05<04:41, 17.3MB/s]
# model-00002-of-00007.safetensors:   2%|     | 116M/4.98G [00:05<04:23, 18.5MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   2%|    | 92.7M/4.95G [00:05<07:29, 10.8MB/s]
#
# model-00004-of-00007.safetensors:   2%|     | 118M/5.00G [00:06<04:18, 18.9MB/s]
# model-00002-of-00007.safetensors:   2%|     | 121M/4.98G [00:06<03:21, 24.1MB/s]
#
#
# model-00007-of-00007.safetensors:   3%|    | 97.8M/3.38G [00:06<04:48, 11.4MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 48.0M/4.93G [00:05<07:11, 11.3MB/s]
#
#
#
# model-00005-of-00007.safetensors:   2%|     | 112M/4.98G [00:06<04:35, 17.7MB/s]
#
# model-00004-of-00007.safetensors:   2%|     | 121M/5.00G [00:06<03:51, 21.0MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   2%|    | 96.0M/4.95G [00:06<06:24, 12.6MB/s]
# model-00002-of-00007.safetensors:   3%|▏    | 125M/4.98G [00:06<03:11, 25.3MB/s]
#
#
# model-00007-of-00007.safetensors:   3%|▏    | 101M/3.38G [00:06<03:57, 13.9MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 51.1M/4.93G [00:05<05:50, 13.9MB/s]
#
#
#
# model-00005-of-00007.safetensors:   2%|     | 119M/4.98G [00:06<03:06, 26.1MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   2%|     | 105M/4.95G [00:06<03:06, 26.0MB/s]
# model-00002-of-00007.safetensors:   3%|▏    | 128M/4.98G [00:06<03:02, 26.6MB/s]
#
#
# model-00006-of-00007.safetensors:   3%|▏    | 136M/4.93G [00:06<03:55, 20.4MB/s]
#
# model-00004-of-00007.safetensors:   2%|     | 124M/5.00G [00:06<03:59, 20.4MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 53.0M/4.93G [00:06<06:04, 13.4MB/s]
#
#
#
# model-00007-of-00007.safetensors:   3%|▏    | 106M/3.38G [00:06<03:20, 16.4MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 127M/5.00G [00:06<04:21, 18.6MB/s]
#
#
# model-00006-of-00007.safetensors:   3%|▏    | 138M/4.93G [00:06<05:23, 14.8MB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:   3%|▏    | 108M/3.38G [00:06<03:49, 14.3MB/s]
# model-00002-of-00007.safetensors:   3%|▏    | 131M/4.98G [00:06<04:58, 16.3MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 58.0M/4.93G [00:06<06:00, 13.5MB/s]
#
#
#
# model-00005-of-00007.safetensors:   3%|▏    | 125M/4.98G [00:06<04:41, 17.3MB/s]
#
#
# model-00006-of-00007.safetensors:   3%|▏    | 140M/4.93G [00:06<05:34, 14.3MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   2%|     | 109M/4.95G [00:06<05:00, 16.1MB/s]
# model-00007-of-00007.safetensors:   3%|▏    | 109M/3.38G [00:06<03:50, 14.2MB/s]
#
#
# model-00006-of-00007.safetensors:   3%|▏    | 143M/4.93G [00:06<05:07, 15.6MB/s]
# model-00007-of-00007.safetensors:   3%|▏    | 111M/3.38G [00:06<04:14, 12.9MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 129M/5.00G [00:07<07:45, 10.5MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 59.5M/4.93G [00:06<08:19, 9.76MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   2%|     | 112M/4.95G [00:07<05:53, 13.7MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 62.2M/4.93G [00:06<06:33, 12.4MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 133M/5.00G [00:07<06:03, 13.4MB/s]
#
#
#
# model-00005-of-00007.safetensors:   3%|▏    | 128M/4.98G [00:07<06:43, 12.0MB/s]
# model-00002-of-00007.safetensors:   3%|▏    | 139M/4.98G [00:07<05:33, 14.5MB/s]
#
#
# model-00006-of-00007.safetensors:   3%|▏    | 145M/4.93G [00:07<07:01, 11.3MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:   3%|▏    | 113M/3.38G [00:07<06:07, 8.90MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 135M/5.00G [00:07<06:34, 12.3MB/s]
#
#
# model-00006-of-00007.safetensors:   3%|▏    | 148M/4.93G [00:07<06:38, 12.0MB/s]
#
#
#
# model-00005-of-00007.safetensors:   3%|▏    | 132M/4.98G [00:07<06:29, 12.5MB/s]
# model-00002-of-00007.safetensors:   3%|▏    | 143M/4.98G [00:07<05:46, 14.0MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 64.0M/4.93G [00:07<08:48, 9.22MB/s]
#
#
# model-00007-of-00007.safetensors:   3%|▏    | 116M/3.38G [00:07<05:12, 10.5MB/s]
#
#
#
# model-00005-of-00007.safetensors:   3%|▏    | 136M/4.98G [00:07<05:01, 16.1MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   2%|     | 121M/4.95G [00:07<05:32, 14.5MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 136M/5.00G [00:07<07:17, 11.1MB/s]
# model-00002-of-00007.safetensors:   3%|▏    | 145M/4.98G [00:07<05:52, 13.7MB/s]
#
#
# model-00007-of-00007.safetensors:   3%|▏    | 118M/3.38G [00:07<04:43, 11.5MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 68.1M/4.93G [00:07<06:23, 12.7MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   2%|     | 123M/4.95G [00:07<05:18, 15.2MB/s]
#
#
#
# model-00005-of-00007.safetensors:   3%|▏    | 139M/4.98G [00:07<04:43, 17.1MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 140M/5.00G [00:07<05:36, 14.4MB/s]
# model-00007-of-00007.safetensors:   4%|▏    | 121M/3.38G [00:07<04:10, 13.0MB/s]
#
#
#
# model-00005-of-00007.safetensors:   3%|▏    | 141M/4.98G [00:07<04:45, 17.0MB/s]
#
#
# model-00006-of-00007.safetensors:   3%|▏    | 158M/4.93G [00:07<04:40, 17.0MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   1%|    | 69.8M/4.93G [00:07<06:43, 12.1MB/s]
# model-00002-of-00007.safetensors:   3%|▏    | 155M/4.98G [00:07<03:46, 21.3MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:   4%|▏    | 122M/3.38G [00:08<05:23, 10.1MB/s]
#
#
#
# model-00005-of-00007.safetensors:   3%|▏    | 144M/4.98G [00:08<05:37, 14.4MB/s]
# model-00002-of-00007.safetensors:   3%|▏    | 159M/4.98G [00:08<03:26, 23.4MB/s]
#
#
# model-00006-of-00007.safetensors:   3%|▏    | 160M/4.93G [00:08<05:52, 13.6MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 142M/5.00G [00:08<08:11, 9.88MB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:   4%|▏    | 126M/3.38G [00:08<03:42, 14.7MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   2%|    | 74.7M/4.93G [00:07<05:53, 13.7MB/s]
#
#
#
# model-00007-of-00007.safetensors:   4%|▏    | 128M/3.38G [00:08<03:33, 15.3MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 127M/4.95G [00:08<08:08, 9.88MB/s]
# model-00002-of-00007.safetensors:   3%|▏    | 162M/4.98G [00:08<04:24, 18.3MB/s]
#
#
# model-00006-of-00007.safetensors:   3%|▏    | 161M/4.93G [00:08<07:49, 10.2MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   2%|    | 76.5M/4.93G [00:08<06:34, 12.3MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 143M/5.00G [00:08<09:58, 8.12MB/s]
# model-00007-of-00007.safetensors:   4%|▏    | 130M/3.38G [00:08<03:41, 14.7MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 128M/4.95G [00:08<08:13, 9.77MB/s]
#
#
#
# model-00005-of-00007.safetensors:   3%|▏    | 150M/4.98G [00:08<04:56, 16.3MB/s]
#
#
# model-00007-of-00007.safetensors:   4%|▏    | 136M/3.38G [00:08<02:11, 24.7MB/s]
# model-00002-of-00007.safetensors:   3%|▏    | 172M/4.98G [00:08<03:07, 25.6MB/s]
#
#
#
# model-00005-of-00007.safetensors:   3%|▏    | 155M/4.98G [00:08<03:48, 21.2MB/s]
#
#
# model-00006-of-00007.safetensors:   3%|▏    | 170M/4.93G [00:08<04:16, 18.6MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 144M/5.00G [00:08<10:33, 7.67MB/s]
#
#
#
# model-00007-of-00007.safetensors:   4%|▏    | 141M/3.38G [00:08<02:06, 25.7MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 146M/5.00G [00:08<10:39, 7.59MB/s]
#
#
# model-00006-of-00007.safetensors:   3%|▏    | 172M/4.93G [00:08<04:42, 16.9MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   2%|    | 80.0M/4.93G [00:08<07:40, 10.5MB/s]
#
#
#
# model-00005-of-00007.safetensors:   3%|▏    | 160M/4.98G [00:08<03:51, 20.9MB/s]
# model-00002-of-00007.safetensors:   4%|▏    | 176M/4.98G [00:08<03:49, 21.0MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:   4%|▏    | 144M/3.38G [00:08<02:17, 23.6MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 175M/4.93G [00:08<04:31, 17.5MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 148M/5.00G [00:08<08:12, 9.85MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 132M/4.95G [00:08<08:48, 9.11MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   2%|    | 84.2M/4.93G [00:08<06:19, 12.8MB/s]
#
# model-00007-of-00007.safetensors:   4%|▏    | 147M/3.38G [00:09<02:29, 21.6MB/s]
# model-00002-of-00007.safetensors:   4%|▏    | 186M/4.98G [00:09<02:42, 29.6MB/s]
#
#
#
# model-00005-of-00007.safetensors:   3%|▏    | 162M/4.98G [00:09<05:39, 14.2MB/s]
# model-00002-of-00007.safetensors:   4%|▏    | 189M/4.98G [00:09<02:50, 28.1MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   2%|    | 87.7M/4.93G [00:08<05:33, 14.5MB/s]
#
#
# model-00007-of-00007.safetensors:   4%|▏    | 151M/3.38G [00:09<02:42, 19.9MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 135M/4.95G [00:09<08:09, 9.83MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 154M/5.00G [00:09<06:40, 12.1MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   2%|    | 89.6M/4.93G [00:08<05:23, 15.0MB/s]
#
#
#
# model-00005-of-00007.safetensors:   3%|▏    | 166M/4.98G [00:09<05:14, 15.3MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 178M/4.93G [00:09<06:15, 12.7MB/s]
# model-00007-of-00007.safetensors:   5%|▏    | 156M/3.38G [00:09<02:27, 21.9MB/s]
#
#
#
# model-00005-of-00007.safetensors:   3%|▏    | 169M/4.98G [00:09<04:30, 17.8MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 158M/5.00G [00:09<04:54, 16.4MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 137M/4.95G [00:09<08:50, 9.06MB/s]
# model-00002-of-00007.safetensors:   4%|▏    | 200M/4.98G [00:09<02:25, 32.8MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 180M/4.93G [00:09<07:13, 11.0MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   2%|    | 91.7M/4.93G [00:09<06:28, 12.5MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 182M/4.93G [00:09<06:05, 13.0MB/s]
#
#
#
# model-00007-of-00007.safetensors:   5%|▏    | 158M/3.38G [00:09<02:57, 18.2MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 160M/5.00G [00:09<05:55, 13.6MB/s]
# model-00002-of-00007.safetensors:   4%|▏    | 204M/4.98G [00:09<02:41, 29.6MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 139M/4.95G [00:09<09:44, 8.23MB/s]
#
#
#
# model-00005-of-00007.safetensors:   3%|▏    | 173M/4.98G [00:09<05:07, 15.7MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 184M/4.93G [00:09<05:39, 14.0MB/s]
#
# model-00007-of-00007.safetensors:   5%|▏    | 160M/3.38G [00:09<03:05, 17.3MB/s]
# model-00002-of-00007.safetensors:   4%|▏    | 207M/4.98G [00:09<02:46, 28.8MB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:   5%|▏    | 162M/3.38G [00:09<03:16, 16.4MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 186M/4.93G [00:09<06:47, 11.7MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 141M/4.95G [00:09<09:16, 8.64MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 163M/5.00G [00:09<07:02, 11.4MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 175M/4.98G [00:09<06:11, 13.0MB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:   5%|▎    | 171M/3.38G [00:10<01:39, 32.3MB/s]
# model-00002-of-00007.safetensors:   4%|▏    | 210M/4.98G [00:10<03:53, 20.4MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 188M/4.93G [00:10<06:12, 12.7MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 165M/5.00G [00:10<06:57, 11.6MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 176M/4.98G [00:10<07:14, 11.1MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   2%|     | 109M/4.93G [00:09<03:31, 22.8MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 190M/4.93G [00:10<05:19, 14.9MB/s]
# model-00007-of-00007.safetensors:   5%|▎    | 175M/3.38G [00:10<01:57, 27.3MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 178M/4.98G [00:10<06:39, 12.0MB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:   5%|▎    | 178M/3.38G [00:10<02:01, 26.5MB/s]
#
# model-00004-of-00007.safetensors:   3%|▏    | 169M/5.00G [00:10<05:51, 13.8MB/s]
# model-00002-of-00007.safetensors:   4%|▏    | 218M/4.98G [00:10<03:40, 21.6MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 183M/4.98G [00:10<04:28, 17.9MB/s]
#
# model-00007-of-00007.safetensors:   5%|▎    | 182M/3.38G [00:10<01:59, 26.7MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 144M/4.95G [00:10<10:43, 7.47MB/s]
# model-00002-of-00007.safetensors:   4%|▏    | 221M/4.98G [00:10<03:37, 21.9MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 192M/4.93G [00:10<07:38, 10.3MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 187M/4.98G [00:10<03:48, 21.0MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 176M/5.00G [00:10<03:52, 20.7MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 195M/4.93G [00:10<05:59, 13.2MB/s]
#
#
#
# model-00007-of-00007.safetensors:   6%|▎    | 187M/3.38G [00:10<01:59, 26.7MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 149M/4.95G [00:10<07:33, 10.6MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 197M/4.93G [00:10<05:50, 13.5MB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:   6%|▎    | 190M/3.38G [00:10<02:00, 26.6MB/s]
# model-00002-of-00007.safetensors:   4%|▏    | 224M/4.98G [00:10<04:42, 16.8MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 202M/4.93G [00:10<03:37, 21.7MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   2%|     | 116M/4.93G [00:10<05:18, 15.1MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 192M/4.98G [00:10<05:10, 15.4MB/s]
#
#
# model-00007-of-00007.safetensors:   6%|▎    | 193M/3.38G [00:11<02:24, 22.0MB/s]
# model-00002-of-00007.safetensors:   5%|▏    | 226M/4.98G [00:11<05:04, 15.6MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 152M/4.95G [00:10<07:03, 11.3MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   2%|     | 119M/4.93G [00:10<05:00, 16.0MB/s]
# model-00002-of-00007.safetensors:   5%|▏    | 233M/4.98G [00:11<03:14, 24.5MB/s]
#
#
# model-00007-of-00007.safetensors:   6%|▎    | 199M/3.38G [00:11<01:52, 28.2MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 154M/4.95G [00:11<07:10, 11.1MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   2%|     | 121M/4.93G [00:10<05:07, 15.6MB/s]
# model-00007-of-00007.safetensors:   6%|▎    | 202M/3.38G [00:11<02:15, 23.4MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 194M/4.98G [00:11<07:24, 10.8MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 156M/4.95G [00:11<07:17, 11.0MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   2%|     | 123M/4.93G [00:11<05:53, 13.6MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 211M/4.93G [00:11<04:39, 16.9MB/s]
# model-00002-of-00007.safetensors:   5%|▏    | 239M/4.98G [00:11<04:28, 17.7MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 195M/4.98G [00:11<08:10, 9.76MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 127M/4.93G [00:11<05:24, 14.8MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 158M/4.95G [00:11<08:04, 9.90MB/s]
#
#
# model-00007-of-00007.safetensors:   6%|▎    | 205M/3.38G [00:11<02:52, 18.5MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 197M/4.98G [00:11<07:34, 10.5MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 178M/5.00G [00:11<12:26, 6.46MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 215M/4.93G [00:11<05:20, 14.7MB/s]
# model-00007-of-00007.safetensors:   6%|▎    | 207M/3.38G [00:11<03:03, 17.3MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 199M/4.98G [00:11<07:12, 11.1MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 128M/4.93G [00:11<06:41, 12.0MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 217M/4.93G [00:11<04:53, 16.1MB/s]
# model-00002-of-00007.safetensors:   5%|▏    | 243M/4.98G [00:11<05:39, 13.9MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 132M/4.93G [00:11<04:54, 16.3MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 180M/5.00G [00:11<11:39, 6.89MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 160M/4.95G [00:11<09:37, 8.29MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 200M/4.98G [00:12<08:42, 9.15MB/s]
#
#
# model-00007-of-00007.safetensors:   6%|▎    | 209M/3.38G [00:12<04:02, 13.1MB/s]
# model-00002-of-00007.safetensors:   5%|▏    | 245M/4.98G [00:12<05:37, 14.0MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 182M/5.00G [00:12<10:35, 7.59MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 164M/4.95G [00:12<06:27, 12.4MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 136M/4.93G [00:11<04:26, 18.0MB/s]
#
#
# model-00006-of-00007.safetensors:   4%|▏    | 221M/4.93G [00:12<05:19, 14.8MB/s]
#
#
#
# model-00007-of-00007.safetensors:   6%|▎    | 213M/3.38G [00:12<03:18, 16.0MB/s]
# model-00002-of-00007.safetensors:   5%|▏    | 246M/4.98G [00:12<05:39, 14.0MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 185M/5.00G [00:12<08:36, 9.32MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 166M/4.95G [00:12<06:34, 12.1MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 138M/4.93G [00:11<04:35, 17.4MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▏    | 223M/4.93G [00:12<05:46, 13.6MB/s]
# model-00002-of-00007.safetensors:   5%|▏    | 248M/4.98G [00:12<05:41, 13.9MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 204M/4.98G [00:12<07:05, 11.2MB/s]
#
# model-00007-of-00007.safetensors:   6%|▎    | 216M/3.38G [00:12<03:46, 14.0MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 140M/4.93G [00:12<05:30, 14.5MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 206M/4.98G [00:12<07:26, 10.7MB/s]
# model-00002-of-00007.safetensors:   5%|▎    | 250M/4.98G [00:12<06:06, 12.9MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 168M/4.95G [00:12<07:28, 10.7MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 141M/4.93G [00:12<05:31, 14.5MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 189M/5.00G [00:12<07:12, 11.1MB/s]
#
#
# model-00007-of-00007.safetensors:   6%|▎    | 217M/3.38G [00:12<03:55, 13.4MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 169M/4.95G [00:12<07:14, 11.0MB/s]
# model-00002-of-00007.safetensors:   5%|▎    | 253M/4.98G [00:12<05:16, 14.9MB/s]
#
#
# model-00007-of-00007.safetensors:   7%|▎    | 220M/3.38G [00:12<03:28, 15.2MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 208M/4.98G [00:12<08:05, 9.83MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   3%|▏    | 173M/4.95G [00:12<05:42, 14.0MB/s]
# model-00002-of-00007.safetensors:   5%|▎    | 256M/4.98G [00:12<05:02, 15.6MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▏    | 234M/4.93G [00:12<03:35, 21.8MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 212M/4.98G [00:12<05:01, 15.8MB/s]
#
# model-00007-of-00007.safetensors:   7%|▎    | 223M/3.38G [00:12<03:13, 16.3MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 144M/4.93G [00:12<07:03, 11.3MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 214M/4.98G [00:12<04:42, 16.9MB/s]
# model-00002-of-00007.safetensors:   5%|▎    | 259M/4.98G [00:12<04:50, 16.3MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▏    | 237M/4.93G [00:12<03:37, 21.6MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 148M/4.93G [00:12<05:06, 15.6MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 193M/5.00G [00:13<08:52, 9.02MB/s]
# model-00002-of-00007.safetensors:   5%|▎    | 260M/4.98G [00:13<05:26, 14.5MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▏    | 239M/4.93G [00:13<04:00, 19.5MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 152M/4.93G [00:12<04:07, 19.3MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 217M/4.98G [00:13<05:19, 14.9MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 176M/4.95G [00:13<07:00, 11.4MB/s]
# model-00002-of-00007.safetensors:   5%|▎    | 265M/4.98G [00:13<03:41, 21.4MB/s]
#
# model-00007-of-00007.safetensors:   7%|▎    | 225M/3.38G [00:13<04:48, 11.0MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 155M/4.93G [00:12<03:38, 21.9MB/s]
#
#
#
# model-00005-of-00007.safetensors:   4%|▏    | 220M/4.98G [00:13<04:28, 17.7MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 178M/4.95G [00:13<06:10, 12.9MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 202M/5.00G [00:13<04:38, 17.2MB/s]
#
#
#
# model-00007-of-00007.safetensors:   7%|▎    | 239M/3.38G [00:13<02:20, 22.5MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▏    | 241M/4.93G [00:13<07:25, 10.5MB/s]
# model-00002-of-00007.safetensors:   5%|▎    | 267M/4.98G [00:13<06:10, 12.7MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 158M/4.93G [00:13<06:39, 12.0MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 180M/4.95G [00:13<11:06, 7.16MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 204M/5.00G [00:13<08:04, 9.90MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 160M/4.93G [00:13<06:35, 12.1MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▏    | 243M/4.93G [00:13<08:30, 9.18MB/s]
# model-00002-of-00007.safetensors:   5%|▎    | 269M/4.98G [00:13<07:14, 10.9MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 181M/4.95G [00:13<10:45, 7.38MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▏    | 245M/4.93G [00:14<07:08, 10.9MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 206M/5.00G [00:14<07:40, 10.4MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 183M/4.95G [00:14<08:53, 8.93MB/s]
# model-00002-of-00007.safetensors:   5%|▎    | 272M/4.98G [00:14<07:13, 10.9MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▎    | 247M/4.93G [00:14<07:12, 10.8MB/s]
#
#
#
# model-00007-of-00007.safetensors:   7%|▎    | 241M/3.38G [00:14<04:33, 11.5MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 186M/4.95G [00:14<07:10, 11.1MB/s]
# model-00002-of-00007.safetensors:   5%|▎    | 274M/4.98G [00:14<06:40, 11.8MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▎    | 251M/4.93G [00:14<05:11, 15.0MB/s]
#
#
#
# model-00005-of-00007.safetensors:   5%|▏    | 229M/4.98G [00:14<07:15, 10.9MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 161M/4.93G [00:14<09:24, 8.45MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 189M/4.95G [00:14<05:22, 14.8MB/s]
#
# model-00007-of-00007.safetensors:   7%|▎    | 246M/3.38G [00:14<03:47, 13.8MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▎    | 253M/4.93G [00:14<04:52, 16.0MB/s]
#
#
#
# model-00005-of-00007.safetensors:   5%|▏    | 231M/4.98G [00:14<06:42, 11.8MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 191M/4.95G [00:14<05:05, 15.6MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 280M/4.98G [00:14<04:34, 17.1MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 166M/4.93G [00:14<06:27, 12.3MB/s]
#
#
#
# model-00005-of-00007.safetensors:   5%|▏    | 233M/4.98G [00:14<06:25, 12.3MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 168M/4.93G [00:14<06:09, 12.9MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▎    | 255M/4.93G [00:14<05:43, 13.6MB/s]
#
# model-00007-of-00007.safetensors:   7%|▎    | 248M/3.38G [00:14<04:52, 10.7MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 282M/4.98G [00:14<06:59, 11.2MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 169M/4.93G [00:14<07:39, 10.4MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 193M/4.95G [00:14<09:23, 8.44MB/s]
#
#
#
# model-00005-of-00007.safetensors:   5%|▏    | 235M/4.98G [00:15<09:28, 8.36MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   3%|▏    | 172M/4.93G [00:14<06:56, 11.4MB/s]
# model-00007-of-00007.safetensors:   7%|▎    | 250M/3.38G [00:15<05:29, 9.50MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▎    | 257M/4.93G [00:15<08:45, 8.90MB/s]
#
# model-00007-of-00007.safetensors:   7%|▎    | 251M/3.38G [00:15<05:27, 9.56MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 284M/4.98G [00:15<07:41, 10.2MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 211M/5.00G [00:15<13:39, 5.84MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▎    | 258M/4.93G [00:15<08:44, 8.92MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 198M/4.95G [00:15<06:11, 12.8MB/s]
#
#
#
# model-00005-of-00007.safetensors:   5%|▏    | 236M/4.98G [00:15<09:21, 8.45MB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:   7%|▎    | 253M/3.38G [00:15<04:53, 10.7MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 212M/5.00G [00:15<13:34, 5.88MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 285M/4.98G [00:15<08:21, 9.36MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 200M/4.95G [00:15<06:22, 12.4MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▎    | 260M/4.93G [00:15<10:27, 7.44MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 213M/5.00G [00:15<13:29, 5.91MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 287M/4.98G [00:15<08:06, 9.65MB/s]
#
#
#
# model-00007-of-00007.safetensors:   8%|▍    | 254M/3.38G [00:15<04:56, 10.6MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 202M/4.95G [00:15<06:39, 11.9MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   4%|▏    | 177M/4.93G [00:15<07:25, 10.7MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▎    | 261M/4.93G [00:15<09:33, 8.15MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 214M/5.00G [00:15<13:09, 6.06MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 288M/4.98G [00:15<07:59, 9.79MB/s]
#
#
#
# model-00005-of-00007.safetensors:   5%|▏    | 238M/4.98G [00:15<10:17, 7.68MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   4%|▏    | 182M/4.93G [00:15<04:57, 16.0MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▎    | 262M/4.93G [00:15<08:01, 9.71MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 215M/5.00G [00:15<10:49, 7.36MB/s]
#
#
#
# model-00005-of-00007.safetensors:   5%|▏    | 239M/4.98G [00:15<09:59, 7.92MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:   8%|▍    | 256M/3.38G [00:15<05:59, 8.71MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 289M/4.98G [00:15<09:41, 8.07MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   4%|▏    | 184M/4.93G [00:15<04:58, 15.9MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▎    | 264M/4.93G [00:15<07:53, 9.86MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 205M/4.95G [00:15<06:41, 11.8MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 216M/5.00G [00:15<09:37, 8.29MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 290M/4.98G [00:15<08:15, 9.47MB/s]
#
#
#
# model-00005-of-00007.safetensors:   5%|▏    | 240M/4.98G [00:15<11:18, 6.99MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▎    | 265M/4.93G [00:15<07:45, 10.0MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 218M/5.00G [00:15<09:44, 8.18MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 292M/4.98G [00:15<07:24, 10.6MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:   8%|▍    | 262M/3.38G [00:16<03:30, 14.8MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   4%|▏    | 187M/4.93G [00:15<04:55, 16.1MB/s]
#
#
#
# model-00005-of-00007.safetensors:   5%|▏    | 241M/4.98G [00:15<11:04, 7.13MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▎    | 266M/4.93G [00:15<07:39, 10.2MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 294M/4.98G [00:16<05:31, 14.1MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:   8%|▍    | 269M/3.38G [00:16<02:21, 22.0MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 220M/5.00G [00:16<07:13, 11.0MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▎    | 269M/4.93G [00:16<05:24, 14.4MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   4%|▏    | 189M/4.93G [00:15<04:59, 15.8MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 296M/4.98G [00:16<06:22, 12.3MB/s]
#
#
#
# model-00005-of-00007.safetensors:   5%|▏    | 245M/4.98G [00:16<07:26, 10.6MB/s]
#
# model-00004-of-00007.safetensors:   4%|▏    | 221M/5.00G [00:16<08:07, 9.80MB/s]
#
#
# model-00006-of-00007.safetensors:   5%|▎    | 270M/4.93G [00:16<06:08, 12.7MB/s]
#
#
#
# model-00007-of-00007.safetensors:   8%|▍    | 272M/3.38G [00:16<02:51, 18.2MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   4%|▏    | 192M/4.93G [00:16<05:49, 13.6MB/s]
#
#
# model-00006-of-00007.safetensors:   6%|▎    | 272M/4.93G [00:16<06:12, 12.5MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 209M/4.95G [00:16<10:02, 7.86MB/s]
#
# model-00007-of-00007.safetensors:   8%|▍    | 277M/3.38G [00:16<02:16, 22.8MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   4%|▏    | 198M/4.93G [00:16<03:50, 20.5MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 304M/4.98G [00:16<03:39, 21.3MB/s]
#
#
# model-00006-of-00007.safetensors:   6%|▎    | 274M/4.93G [00:16<05:50, 13.3MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 210M/4.95G [00:16<09:03, 8.72MB/s]
#
# model-00004-of-00007.safetensors:   5%|▏    | 226M/5.00G [00:16<06:09, 12.9MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   4%|▏    | 201M/4.93G [00:16<03:27, 22.8MB/s]
#
#
# model-00006-of-00007.safetensors:   6%|▎    | 275M/4.93G [00:16<05:51, 13.3MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 306M/4.98G [00:16<03:49, 20.3MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 214M/4.95G [00:16<05:22, 14.7MB/s]
#
# model-00007-of-00007.safetensors:   8%|▍    | 280M/3.38G [00:16<02:18, 22.3MB/s]
#
#
#
# model-00007-of-00007.safetensors:   8%|▍    | 283M/3.38G [00:16<02:29, 20.7MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   4%|▏    | 204M/4.93G [00:16<04:00, 19.7MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 308M/4.98G [00:16<04:33, 17.1MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 216M/4.95G [00:16<05:54, 13.4MB/s]
#
# model-00004-of-00007.safetensors:   5%|▏    | 230M/5.00G [00:16<05:16, 15.1MB/s]
#
#
# model-00006-of-00007.safetensors:   6%|▎    | 276M/4.93G [00:16<07:06, 10.9MB/s]
#
#
#
# model-00007-of-00007.safetensors:   8%|▍    | 285M/3.38G [00:16<02:30, 20.6MB/s]
#
#
# model-00006-of-00007.safetensors:   6%|▎    | 278M/4.93G [00:16<07:04, 11.0MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 310M/4.98G [00:16<04:44, 16.4MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   4%|▏    | 206M/4.93G [00:16<03:59, 19.8MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 219M/4.95G [00:16<05:05, 15.5MB/s]
#
# model-00004-of-00007.safetensors:   5%|▏    | 232M/5.00G [00:16<05:24, 14.7MB/s]
#
#
#
# model-00005-of-00007.safetensors:   5%|▎    | 260M/4.98G [00:16<04:40, 16.9MB/s]
#
#
# model-00007-of-00007.safetensors:   8%|▍    | 287M/3.38G [00:17<02:55, 17.6MB/s]
#
#
#
# model-00005-of-00007.safetensors:   5%|▎    | 263M/4.98G [00:17<04:26, 17.7MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 313M/4.98G [00:17<04:22, 17.8MB/s]
#
# model-00004-of-00007.safetensors:   5%|▏    | 235M/5.00G [00:17<05:02, 15.8MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   4%|▏    | 223M/4.95G [00:17<05:20, 14.7MB/s]
#
#
# model-00006-of-00007.safetensors:   6%|▎    | 282M/4.93G [00:17<05:52, 13.2MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 315M/4.98G [00:17<04:32, 17.1MB/s]
#
# model-00004-of-00007.safetensors:   5%|▏    | 237M/5.00G [00:17<05:28, 14.5MB/s]
#
#
#
# model-00005-of-00007.safetensors:   5%|▎    | 265M/4.98G [00:17<05:10, 15.2MB/s]
#
#
# model-00006-of-00007.safetensors:   6%|▎    | 284M/4.93G [00:17<05:59, 12.9MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 317M/4.98G [00:17<05:03, 15.4MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   4%|▏    | 208M/4.93G [00:17<07:06, 11.1MB/s]
#
#
#
# model-00005-of-00007.safetensors:   5%|▎    | 270M/4.98G [00:17<03:41, 21.3MB/s]
#
#
# model-00006-of-00007.safetensors:   6%|▎    | 285M/4.93G [00:17<06:53, 11.2MB/s]
#
# model-00004-of-00007.safetensors:   5%|▏    | 240M/5.00G [00:17<05:44, 13.8MB/s]
# model-00002-of-00007.safetensors:   6%|▎    | 319M/4.98G [00:17<05:10, 15.0MB/s]
#
#
# model-00006-of-00007.safetensors:   6%|▎    | 286M/4.93G [00:17<06:45, 11.5MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   4%|▏    | 212M/4.93G [00:17<05:57, 13.2MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:   5%|▏    | 224M/4.95G [00:17<08:15, 9.53MB/s]
#
# model-00007-of-00007.safetensors:   9%|▍    | 289M/3.38G [00:17<05:41, 9.05MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:   4%|▏    | 216M/4.93G [00:17<04:42, 16.7MB/s]
#
#
# model-00006-of-00007.safetensors:   6%|▎    | 288M/4.93G [00:17<07:06, 10.9MB/s]
#
# ...
#
#
#
# model-00005-of-00007.safetensors:  41%|█▌  | 2.02G/4.98G [09:48<04:38, 10.6MB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:  84%|███▎| 2.84G/3.38G [09:48<01:02, 8.63MB/s]
#
# model-00004-of-00007.safetensors:  48%|█▉  | 2.41G/5.00G [09:48<05:38, 7.65MB/s]
#
#
# model-00006-of-00007.safetensors:  50%|█▉  | 2.46G/4.93G [09:48<02:30, 16.4MB/s]
# model-00002-of-00007.safetensors:  58%|██▎ | 2.89G/4.98G [09:49<04:30, 7.74MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:  35%|█▍  | 1.73G/4.95G [09:48<03:19, 16.2MB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▌  | 2.02G/4.98G [09:48<04:24, 11.2MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  40%|█▌  | 1.98G/4.93G [09:48<05:53, 8.36MB/s]
#
# model-00004-of-00007.safetensors:  48%|█▉  | 2.41G/5.00G [09:49<06:01, 7.16MB/s]
# model-00007-of-00007.safetensors:  84%|███▎| 2.84G/3.38G [09:49<01:08, 7.95MB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▌  | 2.02G/4.98G [09:49<04:38, 10.6MB/s]
#
#
# model-00006-of-00007.safetensors:  50%|██  | 2.47G/4.93G [09:49<02:33, 16.0MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  40%|█▌  | 1.98G/4.93G [09:48<05:04, 9.68MB/s]
#
# model-00004-of-00007.safetensors:  48%|█▉  | 2.41G/5.00G [09:49<05:14, 8.23MB/s]
# model-00007-of-00007.safetensors:  84%|███▎| 2.84G/3.38G [09:49<00:59, 9.07MB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▌  | 2.02G/4.98G [09:49<04:42, 10.5MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:  84%|███▎| 2.85G/3.38G [09:49<00:56, 9.52MB/s]
#
#
# model-00006-of-00007.safetensors:  50%|██  | 2.48G/4.93G [09:49<01:46, 23.0MB/s]
#
# model-00004-of-00007.safetensors:  48%|█▉  | 2.41G/5.00G [09:49<05:41, 7.57MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  40%|█▌  | 1.98G/4.93G [09:49<07:15, 6.76MB/s]
# model-00002-of-00007.safetensors:  58%|██▎ | 2.89G/4.98G [09:49<04:35, 7.59MB/s]
#
# model-00004-of-00007.safetensors:  48%|█▉  | 2.41G/5.00G [09:49<09:05, 4.74MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:  35%|█▍  | 1.73G/4.95G [09:49<07:34, 7.08MB/s]
#
#
#
# model-00007-of-00007.safetensors:  84%|███▎| 2.85G/3.38G [09:49<01:43, 5.19MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  40%|█▌  | 1.99G/4.93G [09:49<09:19, 5.27MB/s]
#
# model-00004-of-00007.safetensors:  48%|█▉  | 2.41G/5.00G [09:50<07:53, 5.45MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:  84%|███▎| 2.85G/3.38G [09:50<01:43, 5.16MB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▋  | 2.03G/4.98G [09:50<08:42, 5.66MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  40%|█▌  | 1.99G/4.93G [09:49<06:53, 7.12MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:  35%|█▍  | 1.74G/4.95G [09:50<04:29, 11.9MB/s]
#
#
# model-00006-of-00007.safetensors:  50%|██  | 2.48G/4.93G [09:50<03:06, 13.1MB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▋  | 2.03G/4.98G [09:50<05:31, 8.90MB/s]
# model-00002-of-00007.safetensors:  58%|██▎ | 2.90G/4.98G [09:50<06:32, 5.33MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  40%|█▌  | 1.99G/4.93G [09:49<03:48, 12.9MB/s]
#
# model-00004-of-00007.safetensors:  48%|█▉  | 2.42G/5.00G [09:50<07:01, 6.13MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:  84%|███▎| 2.85G/3.38G [09:50<01:42, 5.21MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  40%|█▌  | 2.00G/4.93G [09:50<02:54, 16.8MB/s]
#
# model-00004-of-00007.safetensors:  48%|█▉  | 2.42G/5.00G [09:50<09:58, 4.31MB/s]
# model-00007-of-00007.safetensors:  84%|███▎| 2.85G/3.38G [09:50<02:51, 3.12MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|█▌  | 2.00G/4.93G [09:50<04:37, 10.6MB/s]
#
#
# model-00006-of-00007.safetensors:  50%|██  | 2.49G/4.93G [09:50<03:44, 10.9MB/s]
#
#
#
# model-00007-of-00007.safetensors:  84%|███▎| 2.85G/3.38G [09:51<02:56, 3.03MB/s]
# model-00002-of-00007.safetensors:  58%|██▎ | 2.90G/4.98G [09:51<10:53, 3.19MB/s]
#
#
# model-00006-of-00007.safetensors:  50%|██  | 2.49G/4.93G [09:51<03:32, 11.5MB/s]
#
#
# model-00007-of-00007.safetensors:  84%|███▎| 2.85G/3.38G [09:51<02:06, 4.21MB/s]
#
# model-00004-of-00007.safetensors:  48%|█▉  | 2.42G/5.00G [09:51<06:36, 6.49MB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▋  | 2.03G/4.98G [09:51<09:57, 4.94MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|█▌  | 2.00G/4.93G [09:50<05:51, 8.34MB/s]
#
# model-00007-of-00007.safetensors:  84%|███▍| 2.86G/3.38G [09:51<01:16, 6.94MB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▋  | 2.03G/4.98G [09:51<13:51, 3.55MB/s]
# model-00002-of-00007.safetensors:  58%|██▎ | 2.90G/4.98G [09:51<08:12, 4.23MB/s]
#
#
# model-00006-of-00007.safetensors:  51%|██  | 2.50G/4.93G [09:52<05:24, 7.52MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:  35%|█▍  | 1.75G/4.95G [09:52<11:57, 4.46MB/s]
#
# model-00004-of-00007.safetensors:  48%|█▉  | 2.42G/5.00G [09:52<17:42, 2.42MB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▋  | 2.03G/4.98G [09:52<24:14, 2.03MB/s]
#
#
# model-00006-of-00007.safetensors:  51%|██  | 2.50G/4.93G [09:52<06:58, 5.81MB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▋  | 2.04G/4.98G [09:53<11:39, 4.21MB/s]
#
#
# model-00006-of-00007.safetensors:  51%|██  | 2.51G/4.93G [09:53<04:14, 9.55MB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▋  | 2.04G/4.98G [09:53<14:10, 3.46MB/s]
#
# model-00004-of-00007.safetensors:  49%|█▉  | 2.43G/5.00G [09:53<13:39, 3.14MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:  84%|███▍| 2.86G/3.38G [09:54<04:51, 1.81MB/s]
#
# model-00004-of-00007.safetensors:  49%|█▉  | 2.43G/5.00G [09:54<13:32, 3.16MB/s]
# model-00002-of-00007.safetensors:  58%|██▎ | 2.90G/4.98G [09:55<28:15, 1.23MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:  35%|█▍  | 1.75G/4.95G [09:55<20:56, 2.55MB/s]
#
# model-00004-of-00007.safetensors:  49%|█▉  | 2.43G/5.00G [09:55<17:52, 2.39MB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▋  | 2.04G/4.98G [09:56<32:57, 1.49MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:  35%|█▍  | 1.75G/4.95G [09:56<25:21, 2.10MB/s]
#
# model-00004-of-00007.safetensors:  49%|█▉  | 2.43G/5.00G [09:57<29:50, 1.43MB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▋  | 2.04G/4.98G [09:57<27:43, 1.77MB/s]
#
# model-00007-of-00007.safetensors:  84%|███▍| 2.86G/3.38G [09:57<07:43, 1.13MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|██   | 2.00G/4.93G [09:57<52:37, 928kB/s]
# model-00002-of-00007.safetensors:  58%|██▉  | 2.90G/4.98G [09:58<38:06, 910kB/s]
#
#
# model-00006-of-00007.safetensors:  51%|██  | 2.51G/4.93G [09:59<22:07, 1.83MB/s]
# model-00002-of-00007.safetensors:  58%|██▉  | 2.91G/4.98G [10:00<39:38, 874kB/s]
#
# model-00004-of-00007.safetensors:  49%|█▉  | 2.44G/5.00G [10:00<31:20, 1.36MB/s]
#
#
#
#
# model-00007-of-00007.safetensors:  85%|████▏| 2.86G/3.38G [10:01<11:18, 771kB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|██   | 2.05G/4.98G [10:02<56:35, 866kB/s]
#
#
# model-00006-of-00007.safetensors:  51%|██  | 2.51G/4.93G [10:02<30:13, 1.34MB/s]
# model-00007-of-00007.safetensors:  85%|████▏| 2.86G/3.38G [10:02<10:18, 843kB/s]
#
#
#
#
#
# 00003-of-00007.safetensors:  41%|█▏ | 2.00G/4.93G [10:02<1:03:56, 763kB/s]
# ---------- 2025-02-25 07:34:22 (0:10:03) ----------
# Files:   hashed 18/18 (33.2G/33.2G) | pre-uploaded: 1/8 (11.4M/33.2G) | committed: 0/18 (0.0/33.2G) | ignored: 0
# Workers: hashing: 0 | get upload mode: 0 | pre-uploading: 7 | committing: 0 | waiting: 247
# ---------------------------------------------------
#
#
#
#
# model-00005-of-00007.safetensors:  41%|█▋  | 2.05G/4.98G [10:03<48:39, 1.01MB/s]
# model-00007-of-00007.safetensors:  85%|████▏| 2.86G/3.38G [10:04<10:20, 839kB/s]
#
# model-00004-of-00007.safetensors:  49%|██▍  | 2.44G/5.00G [10:04<48:47, 874kB/s]
#
# model-00004-of-00007.safetensors:  49%|██▍  | 2.44G/5.00G [10:05<51:07, 835kB/s]
# model-00002-of-00007.safetensors:  58%|██▎ | 2.91G/4.98G [10:05<29:06, 1.19MB/s]
#
#
# model-00006-of-00007.safetensors:  51%|██  | 2.51G/4.93G [10:05<35:52, 1.13MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|█▏ | 2.01G/4.93G [10:06<1:15:04, 650kB/s]
#
#
#
# model-00007-of-00007.safetensors:  85%|████▏| 2.86G/3.38G [10:07<14:13, 609kB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▏ | 2.05G/4.98G [10:07<1:11:39, 683kB/s]
#
#
#
#
# model-00001-of-00007.safetensors:  35%|█  | 1.76G/4.95G [10:08<1:42:06, 521kB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|█▏ | 2.01G/4.93G [10:08<1:19:33, 613kB/s]
#
# model-00004-of-00007.safetensors:  49%|█▍ | 2.44G/5.00G [10:09<1:14:59, 569kB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▋  | 2.05G/4.98G [10:09<46:44, 1.05MB/s]
# model-00007-of-00007.safetensors:  85%|████▏| 2.87G/3.38G [10:10<09:28, 908kB/s]
# model-00002-of-00007.safetensors:  58%|██▉  | 2.91G/4.98G [10:10<57:15, 603kB/s]
# model-00002-of-00007.safetensors:  58%|██▎ | 2.92G/4.98G [10:10<28:22, 1.22MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|█▏ | 2.01G/4.93G [10:10<1:14:58, 650kB/s]
# model-00002-of-00007.safetensors:  59%|██▎ | 2.92G/4.98G [10:12<33:43, 1.02MB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|██   | 2.05G/4.98G [10:12<59:07, 826kB/s]
#
#
# model-00007-of-00007.safetensors:  85%|████▏| 2.87G/3.38G [10:13<11:32, 742kB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|█▏ | 2.01G/4.93G [10:13<1:17:56, 625kB/s]
# model-00002-of-00007.safetensors:  59%|██▉  | 2.92G/4.98G [10:14<38:24, 897kB/s]
# model-00002-of-00007.safetensors:  59%|██▎ | 2.92G/4.98G [10:14<31:00, 1.11MB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▏ | 2.06G/4.98G [10:14<1:01:02, 800kB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:  85%|████▏| 2.87G/3.38G [10:15<11:15, 759kB/s]
# model-00002-of-00007.safetensors:  59%|██▉  | 2.92G/4.98G [10:15<39:40, 867kB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|█▏ | 2.01G/4.93G [10:16<1:04:49, 751kB/s]
#
#
#
#
# model-00001-of-00007.safetensors:  35%|█  | 1.76G/4.95G [10:16<2:30:33, 353kB/s]
#
# model-00004-of-00007.safetensors:  49%|█▍ | 2.44G/5.00G [10:17<2:09:19, 330kB/s]
#
#
# model-00006-of-00007.safetensors:  51%|█▌ | 2.52G/4.93G [10:18<1:00:53, 662kB/s]
#
#
#
# model-00007-of-00007.safetensors:  85%|████▏| 2.87G/3.38G [10:18<12:34, 677kB/s]
# model-00002-of-00007.safetensors:  59%|██▉  | 2.92G/4.98G [10:19<52:53, 650kB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|█▏ | 2.01G/4.93G [10:19<1:10:01, 695kB/s]
# model-00007-of-00007.safetensors:  85%|████▏| 2.88G/3.38G [10:21<10:08, 836kB/s]
# model-00002-of-00007.safetensors:  59%|██▉  | 2.92G/4.98G [10:21<42:04, 816kB/s]
#
#
#
# model-00007-of-00007.safetensors:  85%|████▎| 2.88G/3.38G [10:23<11:19, 746kB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|█▏ | 2.02G/4.93G [10:23<1:34:58, 512kB/s]
#
#
#
#
# model-00007-of-00007.safetensors:  85%|████▎| 2.88G/3.38G [10:24<09:30, 886kB/s]
#
#
# model-00007-of-00007.safetensors:  85%|███▍| 2.88G/3.38G [10:25<03:58, 2.09MB/s]
#
#
#
#
# model-00001-of-00007.safetensors:  36%|█  | 1.76G/4.95G [10:25<2:27:23, 361kB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▏ | 2.06G/4.98G [10:25<1:34:18, 517kB/s]
# model-00002-of-00007.safetensors:  59%|██▉  | 2.93G/4.98G [10:25<57:46, 594kB/s]
#
#
#
# model-00007-of-00007.safetensors:  85%|███▍| 2.89G/3.38G [10:26<03:44, 2.21MB/s]
#
# model-00004-of-00007.safetensors:  49%|█▍ | 2.44G/5.00G [10:26<2:48:41, 253kB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▏ | 2.06G/4.98G [10:26<1:08:05, 715kB/s]
#
#
#
# model-00007-of-00007.safetensors:  85%|███▍| 2.89G/3.38G [10:27<03:56, 2.10MB/s]
#
#
# model-00006-of-00007.safetensors:  51%|█▌ | 2.52G/4.93G [10:28<1:25:46, 469kB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:  85%|███▍| 2.89G/3.38G [10:29<06:13, 1.32MB/s]
# model-00002-of-00007.safetensors:  59%|█▊ | 2.93G/4.98G [10:29<1:09:47, 491kB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▏ | 2.06G/4.98G [10:30<1:26:23, 564kB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:  85%|████▎| 2.89G/3.38G [10:32<08:29, 968kB/s]
#
#
# model-00006-of-00007.safetensors:  51%|█▌ | 2.52G/4.93G [10:32<1:32:59, 432kB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|█▏ | 2.02G/4.93G [10:32<1:03:39, 762kB/s]
#
#
#
#
# model-00001-of-00007.safetensors:  36%|█  | 1.76G/4.95G [10:32<3:38:35, 243kB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:  85%|████▎| 2.89G/3.38G [10:33<08:13, 996kB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:  86%|███▍| 2.89G/3.38G [10:34<06:49, 1.20MB/s]
# model-00002-of-00007.safetensors:  59%|█▊ | 2.93G/4.98G [10:34<1:24:01, 408kB/s]
# model-00002-of-00007.safetensors:  59%|█▊ | 2.93G/4.98G [10:35<1:29:41, 382kB/s]
# model-00002-of-00007.safetensors:  59%|██▉  | 2.93G/4.98G [10:35<38:18, 893kB/s]
# model-00002-of-00007.safetensors:  59%|██▎ | 2.93G/4.98G [10:35<31:55, 1.07MB/s]
# model-00007-of-00007.safetensors:  86%|███▍| 2.90G/3.38G [10:36<07:16, 1.12MB/s]
#
#
# model-00006-of-00007.safetensors:  51%|█▌ | 2.52G/4.93G [10:36<1:37:01, 414kB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▏ | 2.06G/4.98G [10:36<2:26:22, 332kB/s]
# model-00002-of-00007.safetensors:  59%|██▎ | 2.94G/4.98G [10:36<19:36, 1.74MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|█▏ | 2.03G/4.93G [10:36<1:11:02, 682kB/s]
# model-00002-of-00007.safetensors:  59%|██▎ | 2.94G/4.98G [10:37<21:20, 1.60MB/s]
#
#
#
# model-00005-of-00007.safetensors:  41%|█▏ | 2.07G/4.98G [10:40<1:21:54, 593kB/s]
#
# model-00007-of-00007.safetensors:  86%|████▎| 2.90G/3.38G [10:40<13:54, 585kB/s]
# model-00007-of-00007.safetensors:  86%|███▍| 2.90G/3.38G [10:42<07:45, 1.04MB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|█▏ | 2.03G/4.93G [10:42<1:52:49, 429kB/s]
#
#
#
#
# model-00001-of-00007.safetensors:  36%|█  | 1.76G/4.95G [10:43<3:38:18, 243kB/s]
#
#
#
# model-00005-of-00007.safetensors:  42%|█▏ | 2.07G/4.98G [10:44<1:35:33, 508kB/s]
# model-00002-of-00007.safetensors:  59%|██▉  | 2.94G/4.98G [10:44<51:34, 661kB/s]
# model-00007-of-00007.safetensors:  86%|████▎| 2.90G/3.38G [10:44<08:53, 903kB/s]
#
#
# model-00007-of-00007.safetensors:  86%|███▍| 2.90G/3.38G [10:45<07:00, 1.14MB/s]
# model-00002-of-00007.safetensors:  59%|██▎ | 2.94G/4.98G [10:45<32:20, 1.05MB/s]
#
#
#
# model-00005-of-00007.safetensors:  42%|█▏ | 2.07G/4.98G [10:46<1:28:34, 548kB/s]
# model-00002-of-00007.safetensors:  59%|██▎ | 2.94G/4.98G [10:46<29:29, 1.15MB/s]
#
#
#
# model-00007-of-00007.safetensors:  86%|███▍| 2.90G/3.38G [10:46<07:21, 1.08MB/s]
#
#
#
#
#
# model-00007-of-00007.safetensors:  86%|████▎| 2.91G/3.38G [10:50<11:28, 694kB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|█▏ | 2.03G/4.93G [10:50<1:53:17, 427kB/s]
#
# model-00004-of-00007.safetensors:  49%|█▍ | 2.45G/5.00G [10:53<3:58:32, 178kB/s]
#
# model-00004-of-00007.safetensors:  49%|█▍ | 2.45G/5.00G [10:53<4:46:49, 148kB/s]
# model-00002-of-00007.safetensors:  59%|█▊ | 2.94G/4.98G [10:53<1:33:55, 362kB/s]
# model-00002-of-00007.safetensors:  59%|█▊ | 2.95G/4.98G [10:54<1:01:16, 554kB/s]
# model-00002-of-00007.safetensors:  59%|██▉  | 2.95G/4.98G [10:54<36:41, 925kB/s]
#
#
#
# model-00005-of-00007.safetensors:  42%|█▏ | 2.08G/4.98G [10:56<1:51:12, 436kB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|█▏ | 2.03G/4.93G [10:57<2:26:05, 331kB/s]
# model-00007-of-00007.safetensors:  86%|████▎| 2.91G/3.38G [10:58<20:41, 384kB/s]
#
#
# model-00006-of-00007.safetensors:  51%|█▌ | 2.52G/4.93G [10:58<3:18:49, 202kB/s]
# model-00002-of-00007.safetensors:  59%|██▉  | 2.95G/4.98G [10:59<44:56, 754kB/s]
# model-00002-of-00007.safetensors:  59%|██▉  | 2.95G/4.98G [11:02<52:20, 647kB/s]
#
#
#
#
# 00007-of-00007.safetensors:  86%|████▎| 2.91G/3.38G [11:03<22:36, 350kB/s]
# ---------- 2025-02-25 07:35:22 (0:11:03) ----------
# Files:   hashed 18/18 (33.2G/33.2G) | pre-uploaded: 1/8 (11.4M/33.2G) | committed: 0/18 (0.0/33.2G) | ignored: 0
# Workers: hashing: 0 | get upload mode: 0 | pre-uploading: 7 | committing: 0 | waiting: 247
# ---------------------------------------------------
#
#
# model-00004-of-00007.safetensors:  49%|█▍ | 2.45G/5.00G [11:04<5:02:15, 141kB/s]
#
#
#
#
# model-00001-of-00007.safetensors:  36%|█  | 1.77G/4.95G [11:05<4:26:16, 199kB/s]
#
#
#
#
# model-00007-of-00007.safetensors:  86%|████▎| 2.91G/3.38G [11:05<20:20, 388kB/s]
#
#
#
#
#
# model-00003-of-00007.safetensors:  41%|█▏ | 2.03G/4.93G [11:05<3:58:58, 202kB/s]
#
#
#
#
# model-00001-of-00007.safetensors:  36%|█  | 1.77G/4.95G [11:06<2:30:22, 352kB/s]
# model-00002-of-00007.safetensors:  59%|█▊ | 2.95G/4.98G [11:06<1:02:21, 543kB/s]
#
#
# model-00006-of-00007.safetensors:  51%|█▌ | 2.53G/4.93G [11:06<3:25:30, 195kB/s]
#
#
#
# model-00005-of-00007.safetensors:  42%|█▎ | 2.08G/4.98G [11:08<3:06:46, 259kB/s]
# model-00002-of-00007.safetensors:  59%|█▊ | 2.96G/4.98G [11:09<1:06:11, 511kB/s]
# model-00002-of-00007.safetensors:  59%|██▉  | 2.96G/4.98G [11:11<57:07, 591kB/s]
#
#
#
#
# model-00007-of-00007.safetensors:  86%|████▎| 2.91G/3.38G [11:13<27:00, 291kB/s]
